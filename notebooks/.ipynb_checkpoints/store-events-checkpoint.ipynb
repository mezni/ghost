# %%
import uuid
from pyspark.sql import SparkSession

def get_spark_session(config):
    spark = SparkSession \
        .builder \
        .appName(config['app_name']) \
        .config("spark.streaming.stopGracefullyOnShutdown", True) \
        .config("spark.jars.packages", "com.datastax.spark:spark-cassandra-connector_2.12:3.4.1,org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0") \
        .config("spark.cassandra.connection.host", config['store_host']) \
        .config("spark.cassandra.connection.port",config['store_port'])\
        .config("spark.cassandra.auth.username", config['store_user']) \
        .config("spark.cassandra.auth.password", config['store_pass']) \
        .config("spark.sql.shuffle.partitions", 4) \
        .master(config['spark_uri']) \
        .getOrCreate()
    return spark

config ={
    "app_name": "store events",
    "store_host": "events-db",
    "store_port": "9042",
    "store_user": "cassandra",
    "store_pass": "cassandra",
    "spark_uri": "spark://spark-master:7077",
    "kafka_bootstrap_servers": "kafka1:19092,kafka2:19093,kafka3:19094",
    "kafka_topic": "events"
}
spark = get_spark_session(config)

# %%
import time
from pyspark.sql.types import StructField, StructType, StringType, IntegerType, LongType
from pyspark.sql.functions import from_json, col, to_timestamp, date_format, lit, count

events_schema = StructType([ 
    StructField('timestamp', StringType(), True),
    StructField('type', StringType(), True),
    StructField('appName', StringType(), True), 
    StructField('appInstance', LongType(), True),
    StructField('appID', StringType(), True),
    StructField('probeID', StringType(), True),
    StructField('eventID', StringType(), True),
    StructField('correletionID', LongType(), True),
    StructField('locationID', StringType(), True),
    StructField('transactionStart', LongType(), True), 
    StructField('transactionEnd', LongType(), True), 
    StructField('transactionDuration', LongType(), True), 
    StructField('clientIPAddress', StringType(), True),
    StructField('clientPort', IntegerType(), True), 
    StructField('serverIPAddress', StringType(), True), 
    StructField('serverPort', IntegerType(), True), 
    StructField('ipProtocol', StringType(), True), 
    StructField('category', StringType(), True), 
    StructField('bytesFromClient', LongType(), True), 
    StructField('bytesToClient', LongType(), True), 
    StructField('bytesFromServer', LongType(), True), 
    StructField('bytesToServer', LongType(), True), 
    StructField('subscriberID', StringType(), True), 
    StructField('applicationProtocol', StringType(), True), 
    StructField('applicationName', StringType(), True), 
    StructField('domain', StringType(), True), 
    StructField('deviceType', StringType(), True), 
    StructField('networkType', StringType(), True), 
    StructField('contentType', StringType(), True), 
    StructField('lostBytesClient', LongType(), True), 
    StructField('lostBytesServer', LongType(), True), 
    StructField('srttMsClient', LongType(), True), 
    StructField('srttMsServer', LongType(), True), 
])


def init_stream(spark, config):    
    df = spark.readStream.format("kafka") \
        .option("kafka.bootstrap.servers", config['kafka_bootstrap_servers']) \
        .option("subscribe", config['kafka_topic']) \
        .option("startingOffsets", "earliest") \
        .option("failOnDataLoss","FALSE") \
        .load() 
    return df

def process_df(df):
    batch_id = str(uuid.uuid4())
    df = df.selectExpr("CAST(value AS STRING)")\
        .select(from_json(col("value"),events_schema)\
        .alias("data"))\
        .withColumn("batchID", lit(batch_id))\
        .select(date_format(to_timestamp("data.transactionEnd"),"yyyyMMddHHmm").alias("bucket_id")\
            ,col("batchID").alias("batch_id")\
            ,col("data.probeID").alias("probe_id")\
            ,col("data.eventID").alias("event_id")\
            ,col("data.locationID").alias("location_id")\
            ,col("data.transactionStart").alias("transaction_start")\
            ,col("data.transactionEnd").alias("transaction_end")\
            ,col("data.transactionDuration").alias("transaction_duration")\
            ,col("data.clientIPAddress").alias("client_ip_address")\
            ,col("data.clientPort").alias("client_port")\
            ,col("data.serverIPAddress").alias("server_ip_address")\
        )
    return df
 
init_df = init_stream(spark, config)
df = process_df(init_df)
#df1 = df.groupBy("batch_id").agg(count("*").alias("cnt"))

query = (df.writeStream\
            .outputMode("append")\
            .format("console")\
            .start())

#query1 = (df1.writeStream\
#            .outputMode("append")\
#            .format("console")\
#            .start())


while query.isActive:
    print (query.lastProgress)
    time.sleep(10)
query.awaitTermination()
#query1.awaitTermination()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:22:30.991Z', 'batchId': 0, 'numInputRows': 197000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 1343.36195080704, 'durationMs': {'addBatch': 136465, 'commitOffsets': 292, 'getBatch': 101, 'latestOffset': 6255, 'queryPlanning': 2797, 'triggerExecution': 146626, 'walCommit': 447}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': None, 'endOffset': {'events': {'2': 66585, '1': 63124, '0': 67291}}, 'latestOffset': {'events': {'2': 66585, '1': 63124, '0': 67291}}, 'numInputRows': 197000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 1343.36195080704, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 197000}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:24:57.799Z', 'batchId': 1, 'numInputRows': 19000, 'inputRowsPerSecond': 129.42074001416816, 'processedRowsPerSecond': 1886.6051037632808, 'durationMs': {'addBatch': 9510, 'commitOffsets': 141, 'getBatch': 2, 'latestOffset': 33, 'queryPlanning': 260, 'triggerExecution': 10071, 'walCommit': 121}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 66585, '1': 63124, '0': 67291}}, 'endOffset': {'events': {'2': 73076, '1': 69182, '0': 73742}}, 'latestOffset': {'events': {'2': 73076, '1': 69182, '0': 73742}}, 'numInputRows': 19000, 'inputRowsPerSecond': 129.42074001416816, 'processedRowsPerSecond': 1886.6051037632808, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 19000}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:25:13.266Z', 'batchId': 3, 'numInputRows': 1000, 'inputRowsPerSecond': 186.11576400521125, 'processedRowsPerSecond': 212.94718909710394, 'durationMs': {'addBatch': 3882, 'commitOffsets': 90, 'getBatch': 10, 'latestOffset': 63, 'queryPlanning': 286, 'triggerExecution': 4696, 'walCommit': 365}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 73624, '1': 69448, '0': 73928}}, 'endOffset': {'events': {'2': 74094, '1': 69645, '0': 74261}}, 'latestOffset': {'events': {'2': 74094, '1': 69645, '0': 74261}}, 'numInputRows': 1000, 'inputRowsPerSecond': 186.11576400521125, 'processedRowsPerSecond': 212.94718909710394, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 1000}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:25:28.468Z', 'batchId': 6, 'numInputRows': 3, 'inputRowsPerSecond': 1.017293997965412, 'processedRowsPerSecond': 1.937984496124031, 'durationMs': {'addBatch': 984, 'commitOffsets': 232, 'getBatch': 2, 'latestOffset': 13, 'queryPlanning': 161, 'triggerExecution': 1548, 'walCommit': 139}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 74762, '1': 70182, '0': 75053}}, 'endOffset': {'events': {'2': 74765, '1': 70182, '0': 75053}}, 'latestOffset': {'events': {'2': 74765, '1': 70182, '0': 75053}}, 'numInputRows': 3, 'inputRowsPerSecond': 1.017293997965412, 'processedRowsPerSecond': 1.937984496124031, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 3}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:25:38.002Z', 'batchId': 10, 'numInputRows': 917, 'inputRowsPerSecond': 536.8852459016393, 'processedRowsPerSecond': 421.80312787488504, 'durationMs': {'addBatch': 1526, 'commitOffsets': 253, 'getBatch': 1, 'latestOffset': 15, 'queryPlanning': 143, 'triggerExecution': 2174, 'walCommit': 224}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 75519, '1': 70383, '0': 75181}}, 'endOffset': {'events': {'2': 75851, '1': 70968, '0': 75181}}, 'latestOffset': {'events': {'2': 75851, '1': 70968, '0': 75181}}, 'numInputRows': 917, 'inputRowsPerSecond': 536.8852459016393, 'processedRowsPerSecond': 421.80312787488504, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 917}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:25:48.115Z', 'batchId': 14, 'numInputRows': 167, 'inputRowsPerSecond': 93.34823923979877, 'processedRowsPerSecond': 85.37832310838446, 'durationMs': {'addBatch': 1365, 'commitOffsets': 225, 'getBatch': 1, 'latestOffset': 11, 'queryPlanning': 126, 'triggerExecution': 1956, 'walCommit': 219}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 76295, '1': 71343, '0': 76195}}, 'endOffset': {'events': {'2': 76385, '1': 71420, '0': 76195}}, 'latestOffset': {'events': {'2': 76385, '1': 71420, '0': 76195}}, 'numInputRows': 167, 'inputRowsPerSecond': 93.34823923979877, 'processedRowsPerSecond': 85.37832310838446, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 167}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:25:55.483Z', 'batchId': 17, 'numInputRows': 192, 'inputRowsPerSecond': 3555.5555555555557, 'processedRowsPerSecond': 72.45283018867924, 'durationMs': {'addBatch': 1623, 'commitOffsets': 828, 'getBatch': 2, 'latestOffset': 70, 'queryPlanning': 44, 'triggerExecution': 2650, 'walCommit': 80}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 76807, '1': 71801, '0': 76392}}, 'endOffset': {'events': {'2': 76807, '1': 71801, '0': 76584}}, 'latestOffset': {'events': {'2': 76807, '1': 71801, '0': 76584}}, 'numInputRows': 192, 'inputRowsPerSecond': 3555.5555555555557, 'processedRowsPerSecond': 72.45283018867924, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 192}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:25:58.165Z', 'batchId': 18, 'numInputRows': 808, 'inputRowsPerSecond': 301.26771066368383, 'processedRowsPerSecond': 108.4272678475577, 'durationMs': {'addBatch': 5673, 'commitOffsets': 792, 'getBatch': 22, 'latestOffset': 45, 'queryPlanning': 250, 'triggerExecution': 7452, 'walCommit': 664}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 76807, '1': 71801, '0': 76584}}, 'endOffset': {'events': {'2': 77155, '1': 71947, '0': 76898}}, 'latestOffset': {'events': {'2': 77155, '1': 71947, '0': 76898}}, 'numInputRows': 808, 'inputRowsPerSecond': 301.26771066368383, 'processedRowsPerSecond': 108.4272678475577, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 808}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:26:12.205Z', 'batchId': 20, 'numInputRows': 938, 'inputRowsPerSecond': 311.0079575596817, 'processedRowsPerSecond': 287.8183491868671, 'durationMs': {'addBatch': 1879, 'commitOffsets': 691, 'getBatch': 0, 'latestOffset': 50, 'queryPlanning': 297, 'triggerExecution': 3259, 'walCommit': 318}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 77184, '1': 71947, '0': 76931}}, 'endOffset': {'events': {'2': 77640, '1': 72159, '0': 77201}}, 'latestOffset': {'events': {'2': 77640, '1': 72159, '0': 77201}}, 'numInputRows': 938, 'inputRowsPerSecond': 311.0079575596817, 'processedRowsPerSecond': 287.8183491868671, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 938}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:26:29.081Z', 'batchId': 23, 'numInputRows': 1, 'inputRowsPerSecond': 37.03703703703704, 'processedRowsPerSecond': 0.9560229445506692, 'durationMs': {'addBatch': 643, 'commitOffsets': 135, 'getBatch': 0, 'latestOffset': 12, 'queryPlanning': 38, 'triggerExecution': 1046, 'walCommit': 217}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 78114, '1': 72505, '0': 77381}}, 'endOffset': {'events': {'2': 78114, '1': 72506, '0': 77381}}, 'latestOffset': {'events': {'2': 78114, '1': 72506, '0': 77381}}, 'numInputRows': 1, 'inputRowsPerSecond': 37.03703703703704, 'processedRowsPerSecond': 0.9560229445506692, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 1}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:26:37.352Z', 'batchId': 26, 'numInputRows': 923, 'inputRowsPerSecond': 500.54229934924075, 'processedRowsPerSecond': 273.0769230769231, 'durationMs': {'addBatch': 2489, 'commitOffsets': 606, 'getBatch': 1, 'latestOffset': 33, 'queryPlanning': 85, 'triggerExecution': 3380, 'walCommit': 165}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 78390, '1': 73306, '0': 77381}}, 'endOffset': {'events': {'2': 78390, '1': 73837, '0': 77773}}, 'latestOffset': {'events': {'2': 78390, '1': 73837, '0': 77773}}, 'numInputRows': 923, 'inputRowsPerSecond': 500.54229934924075, 'processedRowsPerSecond': 273.0769230769231, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 923}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:26:47.499Z', 'batchId': 28, 'numInputRows': 563, 'inputRowsPerSecond': 178.56010149064383, 'processedRowsPerSecond': 190.65357263799527, 'durationMs': {'addBatch': 2129, 'commitOffsets': 482, 'getBatch': 0, 'latestOffset': 13, 'queryPlanning': 102, 'triggerExecution': 2953, 'walCommit': 223}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 78589, '1': 73952, '0': 77896}}, 'endOffset': {'events': {'2': 78971, '1': 74028, '0': 78001}}, 'latestOffset': {'events': {'2': 78971, '1': 74028, '0': 78001}}, 'numInputRows': 563, 'inputRowsPerSecond': 178.56010149064383, 'processedRowsPerSecond': 190.65357263799527, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 563}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:26:54.972Z', 'batchId': 30, 'numInputRows': 999, 'inputRowsPerSecond': 351.7605633802817, 'processedRowsPerSecond': 377.9795686719637, 'durationMs': {'addBatch': 1819, 'commitOffsets': 431, 'getBatch': 0, 'latestOffset': 15, 'queryPlanning': 142, 'triggerExecution': 2643, 'walCommit': 223}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 78972, '1': 74028, '0': 78001}}, 'endOffset': {'events': {'2': 79427, '1': 74326, '0': 78247}}, 'latestOffset': {'events': {'2': 79427, '1': 74326, '0': 78247}}, 'numInputRows': 999, 'inputRowsPerSecond': 351.7605633802817, 'processedRowsPerSecond': 377.9795686719637, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 999}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:27:07.818Z', 'batchId': 33, 'numInputRows': 107, 'inputRowsPerSecond': 3962.962962962963, 'processedRowsPerSecond': 58.56595511767926, 'durationMs': {'addBatch': 956, 'commitOffsets': 342, 'getBatch': 0, 'latestOffset': 61, 'queryPlanning': 38, 'triggerExecution': 1827, 'walCommit': 430}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 79831, '1': 74689, '0': 78480}}, 'endOffset': {'events': {'2': 79938, '1': 74689, '0': 78480}}, 'latestOffset': {'events': {'2': 79938, '1': 74689, '0': 78480}}, 'numInputRows': 107, 'inputRowsPerSecond': 3962.962962962963, 'processedRowsPerSecond': 58.56595511767926, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 107}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:27:17.490Z', 'batchId': 35, 'numInputRows': 841, 'inputRowsPerSecond': 27129.032258064515, 'processedRowsPerSecond': 319.0440060698027, 'durationMs': {'addBatch': 1945, 'commitOffsets': 125, 'getBatch': 0, 'latestOffset': 91, 'queryPlanning': 92, 'triggerExecution': 2636, 'walCommit': 376}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 80277, '1': 74846, '0': 78877}}, 'endOffset': {'events': {'2': 80725, '1': 74930, '0': 79186}}, 'latestOffset': {'events': {'2': 80725, '1': 74930, '0': 79186}}, 'numInputRows': 841, 'inputRowsPerSecond': 27129.032258064515, 'processedRowsPerSecond': 319.0440060698027, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 841}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:27:26.012Z', 'batchId': 37, 'numInputRows': 50, 'inputRowsPerSecond': 1470.5882352941176, 'processedRowsPerSecond': 14.405070584845866, 'durationMs': {'addBatch': 1958, 'commitOffsets': 546, 'getBatch': 4, 'latestOffset': 392, 'queryPlanning': 92, 'triggerExecution': 3471, 'walCommit': 478}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 80884, '1': 74930, '0': 79186}}, 'endOffset': {'events': {'2': 80884, '1': 74980, '0': 79186}}, 'latestOffset': {'events': {'2': 80884, '1': 74980, '0': 79186}}, 'numInputRows': 50, 'inputRowsPerSecond': 1470.5882352941176, 'processedRowsPerSecond': 14.405070584845866, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 50}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:27:35.545Z', 'batchId': 39, 'numInputRows': 1000, 'inputRowsPerSecond': 58823.5294117647, 'processedRowsPerSecond': 251.57232704402514, 'durationMs': {'addBatch': 3312, 'commitOffsets': 340, 'getBatch': 0, 'latestOffset': 91, 'queryPlanning': 82, 'triggerExecution': 3975, 'walCommit': 149}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 81262, '1': 75312, '0': 79426}}, 'endOffset': {'events': {'2': 81473, '1': 76016, '0': 79511}}, 'latestOffset': {'events': {'2': 81473, '1': 76016, '0': 79511}}, 'numInputRows': 1000, 'inputRowsPerSecond': 58823.5294117647, 'processedRowsPerSecond': 251.57232704402514, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 1000}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:27:46.607Z', 'batchId': 40, 'numInputRows': 22, 'inputRowsPerSecond': 628.5714285714286, 'processedRowsPerSecond': 13.048635824436536, 'durationMs': {'addBatch': 1058, 'commitOffsets': 222, 'getBatch': 0, 'latestOffset': 10, 'queryPlanning': 88, 'triggerExecution': 1686, 'walCommit': 291}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 81473, '1': 76016, '0': 79511}}, 'endOffset': {'events': {'2': 81473, '1': 76038, '0': 79511}}, 'latestOffset': {'events': {'2': 81473, '1': 76038, '0': 79511}}, 'numInputRows': 22, 'inputRowsPerSecond': 628.5714285714286, 'processedRowsPerSecond': 13.048635824436536, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 22}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:27:57.135Z', 'batchId': 42, 'numInputRows': 1, 'inputRowsPerSecond': 43.47826086956522, 'processedRowsPerSecond': 0.3451846738004833, 'durationMs': {'addBatch': 1858, 'commitOffsets': 374, 'getBatch': 0, 'latestOffset': 39, 'queryPlanning': 99, 'triggerExecution': 2897, 'walCommit': 526}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 81845, '1': 76146, '0': 80009}}, 'endOffset': {'events': {'2': 81846, '1': 76146, '0': 80009}}, 'latestOffset': {'events': {'2': 81846, '1': 76146, '0': 80009}}, 'numInputRows': 1, 'inputRowsPerSecond': 43.47826086956522, 'processedRowsPerSecond': 0.3451846738004833, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 1}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:28:07.582Z', 'batchId': 45, 'numInputRows': 833, 'inputRowsPerSecond': 390.16393442622956, 'processedRowsPerSecond': 322.61812548412087, 'durationMs': {'addBatch': 1728, 'commitOffsets': 271, 'getBatch': 0, 'latestOffset': 9, 'queryPlanning': 138, 'triggerExecution': 2582, 'walCommit': 435}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 82269, '1': 76393, '0': 80505}}, 'endOffset': {'events': {'2': 82579, '1': 76631, '0': 80790}}, 'latestOffset': {'events': {'2': 82579, '1': 76631, '0': 80790}}, 'numInputRows': 833, 'inputRowsPerSecond': 390.16393442622956, 'processedRowsPerSecond': 322.61812548412087, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 833}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:28:15.414Z', 'batchId': 47, 'numInputRows': 622, 'inputRowsPerSecond': 262.44725738396625, 'processedRowsPerSecond': 216.27260083449235, 'durationMs': {'addBatch': 1827, 'commitOffsets': 490, 'getBatch': 1, 'latestOffset': 41, 'queryPlanning': 64, 'triggerExecution': 2876, 'walCommit': 453}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 82887, '1': 76701, '0': 80790}}, 'endOffset': {'events': {'2': 83141, '1': 76807, '0': 81052}}, 'latestOffset': {'events': {'2': 83141, '1': 76807, '0': 81052}}, 'numInputRows': 622, 'inputRowsPerSecond': 262.44725738396625, 'processedRowsPerSecond': 216.27260083449235, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 622}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:28:28.835Z', 'batchId': 50, 'numInputRows': 239, 'inputRowsPerSecond': 13277.77777777778, 'processedRowsPerSecond': 127.26304579339724, 'durationMs': {'addBatch': 1117, 'commitOffsets': 506, 'getBatch': 0, 'latestOffset': 104, 'queryPlanning': 27, 'triggerExecution': 1878, 'walCommit': 123}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 83301, '1': 76989, '0': 81710}}, 'endOffset': {'events': {'2': 83377, '1': 77152, '0': 81710}}, 'latestOffset': {'events': {'2': 83377, '1': 77152, '0': 81710}}, 'numInputRows': 239, 'inputRowsPerSecond': 13277.77777777778, 'processedRowsPerSecond': 127.26304579339724, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 239}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:28:38.622Z', 'batchId': 52, 'numInputRows': 125, 'inputRowsPerSecond': 7352.941176470587, 'processedRowsPerSecond': 61.45526057030482, 'durationMs': {'addBatch': 848, 'commitOffsets': 863, 'getBatch': 0, 'latestOffset': 14, 'queryPlanning': 52, 'triggerExecution': 2034, 'walCommit': 256}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 83873, '1': 77346, '0': 81781}}, 'endOffset': {'events': {'2': 83873, '1': 77471, '0': 81781}}, 'latestOffset': {'events': {'2': 83873, '1': 77471, '0': 81781}}, 'numInputRows': 125, 'inputRowsPerSecond': 7352.941176470587, 'processedRowsPerSecond': 61.45526057030482, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 125}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:28:47.444Z', 'batchId': 54, 'numInputRows': 942, 'inputRowsPerSecond': 26166.666666666668, 'processedRowsPerSecond': 381.06796116504853, 'durationMs': {'addBatch': 1553, 'commitOffsets': 478, 'getBatch': 0, 'latestOffset': 101, 'queryPlanning': 88, 'triggerExecution': 2472, 'walCommit': 251}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 83990, '1': 77852, '0': 82158}}, 'endOffset': {'events': {'2': 84334, '1': 78450, '0': 82158}}, 'latestOffset': {'events': {'2': 84334, '1': 78450, '0': 82158}}, 'numInputRows': 942, 'inputRowsPerSecond': 26166.666666666668, 'processedRowsPerSecond': 381.06796116504853, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 942}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:28:57.136Z', 'batchId': 57, 'numInputRows': 680, 'inputRowsPerSecond': 226.06382978723406, 'processedRowsPerSecond': 256.4102564102564, 'durationMs': {'addBatch': 1612, 'commitOffsets': 292, 'getBatch': 0, 'latestOffset': 7, 'queryPlanning': 172, 'triggerExecution': 2652, 'walCommit': 568}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 84515, '1': 78551, '0': 82254}}, 'endOffset': {'events': {'2': 84707, '1': 78883, '0': 82410}}, 'latestOffset': {'events': {'2': 84707, '1': 78883, '0': 82410}}, 'numInputRows': 680, 'inputRowsPerSecond': 226.06382978723406, 'processedRowsPerSecond': 256.4102564102564, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 680}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:29:09.703Z', 'batchId': 60, 'numInputRows': 192, 'inputRowsPerSecond': 9600.0, 'processedRowsPerSecond': 141.3843888070692, 'durationMs': {'addBatch': 854, 'commitOffsets': 202, 'getBatch': 0, 'latestOffset': 50, 'queryPlanning': 28, 'triggerExecution': 1358, 'walCommit': 222}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 84814, '1': 79218, '0': 82968}}, 'endOffset': {'events': {'2': 84900, '1': 79324, '0': 82968}}, 'latestOffset': {'events': {'2': 84900, '1': 79324, '0': 82968}}, 'numInputRows': 192, 'inputRowsPerSecond': 9600.0, 'processedRowsPerSecond': 141.3843888070692, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 192}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:29:17.291Z', 'batchId': 63, 'numInputRows': 815, 'inputRowsPerSecond': 480.54245283018867, 'processedRowsPerSecond': 271.2146422628952, 'durationMs': {'addBatch': 2308, 'commitOffsets': 386, 'getBatch': 0, 'latestOffset': 7, 'queryPlanning': 126, 'triggerExecution': 3005, 'walCommit': 154}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 85367, '1': 79510, '0': 83308}}, 'endOffset': {'events': {'2': 85755, '1': 79694, '0': 83551}}, 'latestOffset': {'events': {'2': 85755, '1': 79694, '0': 83551}}, 'numInputRows': 815, 'inputRowsPerSecond': 480.54245283018867, 'processedRowsPerSecond': 271.2146422628952, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 815}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:29:29.255Z', 'batchId': 66, 'numInputRows': 296, 'inputRowsPerSecond': 10962.962962962964, 'processedRowsPerSecond': 438.5185185185185, 'durationMs': {'addBatch': 357, 'commitOffsets': 158, 'getBatch': 0, 'latestOffset': 14, 'queryPlanning': 23, 'triggerExecution': 675, 'walCommit': 123}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 85876, '1': 80111, '0': 84013}}, 'endOffset': {'events': {'2': 86172, '1': 80111, '0': 84013}}, 'latestOffset': {'events': {'2': 86172, '1': 80111, '0': 84013}}, 'numInputRows': 296, 'inputRowsPerSecond': 10962.962962962964, 'processedRowsPerSecond': 438.5185185185185, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 296}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:29:36.690Z', 'batchId': 69, 'numInputRows': 999, 'inputRowsPerSecond': 480.98218584496874, 'processedRowsPerSecond': 618.1930693069306, 'durationMs': {'addBatch': 1167, 'commitOffsets': 200, 'getBatch': 1, 'latestOffset': 15, 'queryPlanning': 34, 'triggerExecution': 1616, 'walCommit': 198}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 86414, '1': 80443, '0': 84144}}, 'endOffset': {'events': {'2': 86775, '1': 80592, '0': 84633}}, 'latestOffset': {'events': {'2': 86775, '1': 80592, '0': 84633}}, 'numInputRows': 999, 'inputRowsPerSecond': 480.98218584496874, 'processedRowsPerSecond': 618.1930693069306, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 999}}
# {'id': '70e524ad-41d7-4fd6-b083-1655eaab66e9', 'runId': 'aa0257fb-32c8-4569-b56b-f47bce79de45', 'name': None, 'timestamp': '2023-11-27T01:29:44.832Z', 'batchId': 71, 'numInputRows': 999, 'inputRowsPerSecond': 510.2145045965271, 'processedRowsPerSecond': 350.2805049088359, 'durationMs': {'addBatch': 2087, 'commitOffsets': 364, 'getBatch': 0, 'latestOffset': 22, 'queryPlanning': 104, 'triggerExecution': 2852, 'walCommit': 273}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[events]]', 'startOffset': {'events': {'2': 86775, '1': 80592, '0': 84634}}, 'endOffset': {'events': {'2': 86861, '1': 81242, '0': 84897}}, 'latestOffset': {'events': {'2': 86861, '1': 81242, '0': 84897}}, 'numInputRows': 999, 'inputRowsPerSecond': 510.2145045965271, 'processedRowsPerSecond': 350.2805049088359, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@e0b9013', 'numOutputRows': 999}}
